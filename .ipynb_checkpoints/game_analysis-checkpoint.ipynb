# %%
# %matplotlib notebook
import pandas as pd
import matplotlib as mlp
import matplotlib.pyplot as plt

# %%
df=pd.read_csv('vgsales.csv')
df.head()
# Out:
#    Rank                      Name Platform    Year         Genre Publisher  \
# 0     1                Wii Sports      Wii  2006.0        Sports  Nintendo
# 1     2         Super Mario Bros.      NES  1985.0      Platform  Nintendo
# 2     3            Mario Kart Wii      Wii  2008.0        Racing  Nintendo
# 3     4         Wii Sports Resort      Wii  2009.0        Sports  Nintendo
# 4     5  Pokemon Red/Pokemon Blue       GB  1996.0  Role-Playing  Nintendo
#
#    NA_Sales  EU_Sales  JP_Sales  Other_Sales  Global_Sales
# 0     41.49     29.02      3.77         8.46         82.74
# 1     29.08      3.58      6.81         0.77         40.24
# 2     15.85     12.88      3.79         3.31         35.82
# 3     15.75     11.01      3.28         2.96         33.00
# 4     11.27      8.89     10.22         1.00         31.37

# %%
df=pd.read_csv('vgsales.csv')
df=df[(df['Year']>=2000) & (df['Year']<=2010)]
df=df[['Year','Platform','NA_Sales','EU_Sales','JP_Sales','Other_Sales']]
df=df.replace(['PS','PS2','PS3'],'PS')
df=df.replace(['X360','XB'],'Xbox')
df=df[df['Platform'].isin(['PS','Xbox','PC'])]
df.Year=df.Year.astype(int)
df.head()
# Out:
#     Year Platform  NA_Sales  EU_Sales  JP_Sales  Other_Sales
# 15  2010     Xbox     14.97      4.94      0.24         1.67
# 17  2004       PS      9.43      0.40      0.41        10.57
# 24  2002       PS      8.41      5.49      0.47         1.78
# 28  2001       PS      6.85      5.09      1.87         1.16
# 31  2010     Xbox      9.67      3.73      0.11         1.13

# %%
sales_min=min(df['NA_Sales'])
sales_max=max(df['NA_Sales'])
first_year=min(df['Year'])
last_year=max(df['Year'])
df=df.groupby(['Year']).sum()
df
# Out:
#       NA_Sales  EU_Sales  JP_Sales  Other_Sales
# Year
# 2000     65.78     42.83     23.47         9.08
# 2001    116.02     71.98     22.02        19.76
# 2002    138.40     82.11     23.98        24.14
# 2003    127.42     80.39     19.18        23.34
# 2004    147.78     78.15     19.45        42.24
# 2005    128.71     56.53     15.35        21.86
# 2006    101.99     44.37     19.91        23.10
# 2007    130.32     65.94     15.56        43.73
# 2008    161.55     95.85     13.45        51.22
# 2009    147.29     94.79     12.92        41.80
# 2010    179.45    113.20     12.69        40.05

# %%
years=list(range(first_year,last_year+1))
years_str = [str(i) for i in range(first_year,last_year+1)]
df.plot()
plt.title('Video Games Sales')
plt.xlabel('Years')
plt.ylabel('Sales(in million dollars)')
plt.xlim(first_year,last_year)
plt.xticks(years,years_str)
# Out:
# <img src="data:image/png;base64,..." width="640">
# ([<matplotlib.axis.XTick at 0x189d2b31eb0>,
# ...
#  [Text(0, 0, '2000'),
#   Text(0, 0, '2001'),
#   Text(0, 0, '2002'),
#   Text(0, 0, '2003'),
#   Text(0, 0, '2004'),
#   Text(0, 0, '2005'),
#   Text(0, 0, '2006'),
#   Text(0, 0, '2007'),
#   Text(0, 0, '2008'),
#   Text(0, 0, '2009'),
#   Text(0, 0, '2010')])
